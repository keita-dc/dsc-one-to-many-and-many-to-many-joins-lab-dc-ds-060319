# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
import sqlite3
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
cur.execute('''
    SELECT firstName, lastName, city, state
    FROM employees
    JOIN offices
    USING (officeCode)
    ''').fetchall()
# Out:
# [('Diane', 'Murphy', 'San Francisco', 'CA'),
#  ('Mary', 'Patterson', 'San Francisco', 'CA'),
#  ('Jeff', 'Firrelli', 'San Francisco', 'CA'),
#  ('William', 'Patterson', 'Sydney', ''),
#  ('Gerard', 'Bondur', 'Paris', ''),
#  ('Anthony', 'Bow', 'San Francisco', 'CA'),
#  ('Leslie', 'Jennings', 'San Francisco', 'CA'),
#  ('Leslie', 'Thompson', 'San Francisco', 'CA'),
#  ('Julie', 'Firrelli', 'Boston', 'MA'),
#  ('Steve', 'Patterson', 'Boston', 'MA'),
#  ('Foon Yue', 'Tseng', 'NYC', 'NY'),
#  ('George', 'Vanauf', 'NYC', 'NY'),
#  ('Loui', 'Bondur', 'Paris', ''),
#  ('Gerard', 'Hernandez', 'Paris', ''),
#  ('Pamela', 'Castillo', 'Paris', ''),
#  ('Larry', 'Bott', 'London', ''),
#  ('Barry', 'Jones', 'London', ''),
#  ('Andy', 'Fixter', 'Sydney', ''),
#  ('Peter', 'Marsh', 'Sydney', ''),
#  ('Tom', 'King', 'Sydney', ''),
#  ('Mami', 'Nishi', 'Tokyo', 'Chiyoda-Ku'),
#  ('Yoshimi', 'Kato', 'Tokyo', 'Chiyoda-Ku'),
#  ('Martin', 'Gerard', 'Paris', '')]

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
cur.execute('''
    SELECT contactFirstName, contactLastName, orderNumber
    FROM customers
    JOIN orders
    USING(customerNumber)''').fetchall()
# Out:
# [('Carine ', 'Schmitt', '10123'),
#  ('Carine ', 'Schmitt', '10298'),
#  ('Carine ', 'Schmitt', '10345'),
#  ('Jean', 'King', '10124'),
#  ('Jean', 'King', '10278'),
#  ('Jean', 'King', '10346'),
#  ('Peter', 'Ferguson', '10120'),
#  ('Peter', 'Ferguson', '10125'),
#  ('Peter', 'Ferguson', '10223'),
#  ('Peter', 'Ferguson', '10342'),
#  ('Peter', 'Ferguson', '10347'),
#  ('Janine ', 'Labrune', '10275'),
#  ('Janine ', 'Labrune', '10315'),
#  ('Janine ', 'Labrune', '10375'),
#  ('Janine ', 'Labrune', '10425'),
#  ('Jonas ', 'Bergulfsen', '10103'),
#  ('Jonas ', 'Bergulfsen', '10158'),
#  ('Jonas ', 'Bergulfsen', '10309'),
#  ('Jonas ', 'Bergulfsen', '10325'),
#  ('Susan', 'Nelson', '10113'),
#  ('Susan', 'Nelson', '10135'),
#  ('Susan', 'Nelson', '10142'),
#  ('Susan', 'Nelson', '10182'),
#  ('Susan', 'Nelson', '10229'),
#  ('Susan', 'Nelson', '10271'),
#  ('Susan', 'Nelson', '10282'),
#  ('Susan', 'Nelson', '10312'),
#  ('Susan', 'Nelson', '10335'),
#  ('Susan', 'Nelson', '10357'),
#  ('Susan', 'Nelson', '10368'),
#  ('Susan', 'Nelson', '10371'),
#  ('Susan', 'Nelson', '10382'),
#  ('Susan', 'Nelson', '10385'),
#  ('Susan', 'Nelson', '10390'),
#  ('Susan', 'Nelson', '10396'),
#  ('Susan', 'Nelson', '10421'),
#  ('Roland', 'Keitel', '10101'),
#  ('Roland', 'Keitel', '10230'),
#  ('Roland', 'Keitel', '10300'),
#  ('Roland', 'Keitel', '10323'),
#  ('Julie', 'Murphy', '10111'),
#  ('Julie', 'Murphy', '10201'),
#  ('Julie', 'Murphy', '10333'),
#  ('Kwai', 'Lee', '10107'),
#  ('Kwai', 'Lee', '10248'),
#  ('Kwai', 'Lee', '10292'),
#  ('Kwai', 'Lee', '10329'),
#  ('Diego ', 'Freyre', '10104'),
#  ('Diego ', 'Freyre', '10128'),
#  ('Diego ', 'Freyre', '10133'),
#  ('Diego ', 'Freyre', '10153'),
#  ('Diego ', 'Freyre', '10156'),
#  ('Diego ', 'Freyre', '10190'),
#  ('Diego ', 'Freyre', '10203'),
#  ('Diego ', 'Freyre', '10205'),
#  ('Diego ', 'Freyre', '10212'),
#  ('Diego ', 'Freyre', '10244'),
#  ('Diego ', 'Freyre', '10246'),
#  ('Diego ', 'Freyre', '10262'),
#  ('Diego ', 'Freyre', '10279'),
#  ('Diego ', 'Freyre', '10311'),
#  ('Diego ', 'Freyre', '10350'),
#  ('Diego ', 'Freyre', '10355'),
#  ('Diego ', 'Freyre', '10358'),
#  ('Diego ', 'Freyre', '10378'),
#  ('Diego ', 'Freyre', '10379'),
#  ('Diego ', 'Freyre', '10380'),
#  ('Diego ', 'Freyre', '10383'),
#  ('Diego ', 'Freyre', '10386'),
#  ('Diego ', 'Freyre', '10394'),
#  ('Diego ', 'Freyre', '10412'),
#  ('Diego ', 'Freyre', '10417'),
#  ('Diego ', 'Freyre', '10424'),
#  ('Christina ', 'Berglund', '10112'),
#  ('Christina ', 'Berglund', '10320'),
#  ('Christina ', 'Berglund', '10326'),
#  ('Christina ', 'Berglund', '10334'),
#  ('Jytte ', 'Petersen', '10105'),
#  ('Jytte ', 'Petersen', '10238'),
#  ('Jytte ', 'Petersen', '10256'),
#  ('Jytte ', 'Petersen', '10327'),
#  ('Jytte ', 'Petersen', '10406'),
#  ('Mary ', 'Saveley', '10194'),
#  ('Mary ', 'Saveley', '10208'),
#  ('Mary ', 'Saveley', '10227'),
#  ('Eric', 'Natividad', '10117'),
#  ('Eric', 'Natividad', '10150'),
#  ('Eric', 'Natividad', '10165'),
#  ('Eric', 'Natividad', '10277'),
#  ('Eric', 'Natividad', '10387'),
#  ('Jeff', 'Young', '10127'),
#  ('Jeff', 'Young', '10204'),
#  ('Jeff', 'Young', '10267'),
#  ('Jeff', 'Young', '10349'),
#  ('Kelvin', 'Leong', '10272'),
#  ('Kelvin', 'Leong', '10281'),
#  ('Kelvin', 'Leong', '10318'),
#  ('Kelvin', 'Leong', '10422'),
#  ('Juri', 'Hashimoto', '10140'),
#  ('Juri', 'Hashimoto', '10168'),
#  ('Juri', 'Hashimoto', '10317'),
#  ('Juri', 'Hashimoto', '10362'),
#  ('Wendy', 'Victorino', '10217'),
#  ('Wendy', 'Victorino', '10259'),
#  ('Wendy', 'Victorino', '10288'),
#  ('Wendy', 'Victorino', '10409'),
#  ('Veysel', 'Oeztan', '10181'),
#  ('Veysel', 'Oeztan', '10188'),
#  ('Veysel', 'Oeztan', '10289'),
#  ('Martine ', 'Rancé', '10180'),
#  ('Martine ', 'Rancé', '10224'),
#  ('Marie', 'Bertrand', '10114'),
#  ('Marie', 'Bertrand', '10286'),
#  ('Marie', 'Bertrand', '10336'),
#  ('Jerry', 'Tseng', '10228'),
#  ('Jerry', 'Tseng', '10249'),
#  ('Julie', 'King', '10172'),
#  ('Julie', 'King', '10263'),
#  ('Julie', 'King', '10413'),
#  ('Mory', 'Kentary', '10210'),
#  ('Mory', 'Kentary', '10240'),
#  ('Michael', 'Frick', '10102'),
#  ('Michael', 'Frick', '10237'),
#  ('Michael', 'Frick', '10324'),
#  ('Matti', 'Karttunen', '10155'),
#  ('Matti', 'Karttunen', '10299'),
#  ('Matti', 'Karttunen', '10377'),
#  ('Rachel', 'Ashworth', '10110'),
#  ('Rachel', 'Ashworth', '10306'),
#  ('Rachel', 'Ashworth', '10332'),
#  ('Dean', 'Cassidy', '10220'),
#  ('Dean', 'Cassidy', '10297'),
#  ('Leslie', 'Taylor', '10130'),
#  ('Leslie', 'Taylor', '10290'),
#  ('Leslie', 'Taylor', '10352'),
#  ('Elizabeth', 'Devon', '10253'),
#  ('Elizabeth', 'Devon', '10302'),
#  ('Elizabeth', 'Devon', '10403'),
#  ('Yoshi ', 'Tamuri', '10206'),
#  ('Yoshi ', 'Tamuri', '10313'),
#  ('Miguel', 'Barajas', '10276'),
#  ('Miguel', 'Barajas', '10294'),
#  ('Julie', 'Young', '10145'),
#  ('Julie', 'Young', '10189'),
#  ('Julie', 'Young', '10367'),
#  ('Frédérique ', 'Citeaux', '10241'),
#  ('Frédérique ', 'Citeaux', '10255'),
#  ('Frédérique ', 'Citeaux', '10405'),
#  ('Mike', 'Gao', '10187'),
#  ('Mike', 'Gao', '10200'),
#  ('Eduardo ', 'Saavedra', '10118'),
#  ('Eduardo ', 'Saavedra', '10197'),
#  ('Eduardo ', 'Saavedra', '10340'),
#  ('Mary', 'Young', '10154'),
#  ('Mary', 'Young', '10376'),
#  ('Palle', 'Ibsen', '10161'),
#  ('Palle', 'Ibsen', '10314'),
#  ('Jean ', 'Fresnière', '10171'),
#  ('Jean ', 'Fresnière', '10261'),
#  ('Jean ', 'Fresnière', '10411'),
#  ('Valarie', 'Thompson', '10222'),
#  ('Valarie', 'Thompson', '10226'),
#  ('Helen ', 'Bennett', '10232'),
#  ('Helen ', 'Bennett', '10316'),
#  ('Annette ', 'Roulet', '10136'),
#  ('Annette ', 'Roulet', '10178'),
#  ('Annette ', 'Roulet', '10397'),
#  ('Paolo ', 'Accorti', '10280'),
#  ('Paolo ', 'Accorti', '10293'),
#  ('Daniel', 'Da Silva', '10134'),
#  ('Daniel', 'Da Silva', '10356'),
#  ('Daniel', 'Da Silva', '10395'),
#  ('Daniel ', 'Tonini', '10216'),
#  ('Daniel ', 'Tonini', '10304'),
#  ('Henriette ', 'Pfalzheim', '10191'),
#  ('Henriette ', 'Pfalzheim', '10310'),
#  ('Elizabeth ', 'Lincoln', '10235'),
#  ('Elizabeth ', 'Lincoln', '10283'),
#  ('Anna', "O'Hara", '10148'),
#  ('Anna', "O'Hara", '10169'),
#  ('Anna', "O'Hara", '10370'),
#  ('Anna', "O'Hara", '10391'),
#  ('Giovanni ', 'Rovelli', '10106'),
#  ('Giovanni ', 'Rovelli', '10173'),
#  ('Giovanni ', 'Rovelli', '10328'),
#  ('Adrian', 'Huxley', '10139'),
#  ('Adrian', 'Huxley', '10270'),
#  ('Adrian', 'Huxley', '10361'),
#  ('Adrian', 'Huxley', '10420'),
#  ('Marta', 'Hernandez', '10285'),
#  ('Marta', 'Hernandez', '10305'),
#  ('Mihael', 'Holz', '10225'),
#  ('Mihael', 'Holz', '10287'),
#  ('Jan', 'Klaeboe', '10284'),
#  ('Jan', 'Klaeboe', '10301'),
#  ('Pirkko', 'Koskitalo', '10151'),
#  ('Pirkko', 'Koskitalo', '10239'),
#  ('Pirkko', 'Koskitalo', '10373'),
#  ('Catherine ', 'Dewey', '10221'),
#  ('Catherine ', 'Dewey', '10273'),
#  ('Catherine ', 'Dewey', '10423'),
#  ('Steve', 'Frick', '10195'),
#  ('Steve', 'Frick', '10308'),
#  ('Wing', 'Huang', '10143'),
#  ('Wing', 'Huang', '10185'),
#  ('Wing', 'Huang', '10365'),
#  ('Julie', 'Brown', '10159'),
#  ('Julie', 'Brown', '10162'),
#  ('Julie', 'Brown', '10381'),
#  ('Julie', 'Brown', '10384'),
#  ('Mike', 'Graham', '10132'),
#  ('Mike', 'Graham', '10254'),
#  ('Mike', 'Graham', '10354'),
#  ('Mike', 'Graham', '10393'),
#  ('Mike', 'Graham', '10404'),
#  ('Ann ', 'Brown', '10129'),
#  ('Ann ', 'Brown', '10175'),
#  ('Ann ', 'Brown', '10351'),
#  ('William', 'Brown', '10233'),
#  ('William', 'Brown', '10251'),
#  ('William', 'Brown', '10401'),
#  ('Ben', 'Calaghan', '10152'),
#  ('Ben', 'Calaghan', '10174'),
#  ('Ben', 'Calaghan', '10374'),
#  ('Kalle', 'Suominen', '10141'),
#  ('Kalle', 'Suominen', '10247'),
#  ('Kalle', 'Suominen', '10363'),
#  ('Francisca', 'Cervantes', '10183'),
#  ('Francisca', 'Cervantes', '10307'),
#  ('Jesus', 'Fernandez', '10177'),
#  ('Jesus', 'Fernandez', '10231'),
#  ('Brian', 'Chandler', '10160'),
#  ('Brian', 'Chandler', '10209'),
#  ('Laurence ', 'Lebihan', '10122'),
#  ('Laurence ', 'Lebihan', '10344'),
#  ('Laurence ', 'Lebihan', '10364'),
#  ('Paul ', 'Henriot', '10121'),
#  ('Paul ', 'Henriot', '10137'),
#  ('Paul ', 'Henriot', '10343'),
#  ('Paul ', 'Henriot', '10359'),
#  ('Paul ', 'Henriot', '10398'),
#  ('Wales', 'MacKinlay', '10202'),
#  ('Wales', 'MacKinlay', '10260'),
#  ('Wales', 'MacKinlay', '10410'),
#  ('Juri', 'Yoshido', '10264'),
#  ('Juri', 'Yoshido', '10295'),
#  ('Juri', 'Yoshido', '10414'),
#  ('Dorothy', 'Young', '10100'),
#  ('Dorothy', 'Young', '10192'),
#  ('Dorothy', 'Young', '10322'),
#  ('Allen', 'Nelson', '10147'),
#  ('Allen', 'Nelson', '10274'),
#  ('Allen', 'Nelson', '10369'),
#  ('Pascale ', 'Cartrain', '10116'),
#  ('Pascale ', 'Cartrain', '10144'),
#  ('Pascale ', 'Cartrain', '10338'),
#  ('Pascale ', 'Cartrain', '10366'),
#  ('Georg ', 'Pipps', '10119'),
#  ('Georg ', 'Pipps', '10269'),
#  ('Georg ', 'Pipps', '10341'),
#  ('Georg ', 'Pipps', '10419'),
#  ('Arnold', 'Cruz', '10108'),
#  ('Arnold', 'Cruz', '10198'),
#  ('Arnold', 'Cruz', '10330'),
#  ('Maurizio ', 'Moroni', '10176'),
#  ('Maurizio ', 'Moroni', '10266'),
#  ('Maurizio ', 'Moroni', '10416'),
#  ('Akiko', 'Shimamura', '10258'),
#  ('Akiko', 'Shimamura', '10339'),
#  ('Akiko', 'Shimamura', '10372'),
#  ('Akiko', 'Shimamura', '10408'),
#  ('Dominique', 'Perrier', '10211'),
#  ('Dominique', 'Perrier', '10252'),
#  ('Dominique', 'Perrier', '10402'),
#  ('Sarah', 'McRoy', '10234'),
#  ('Sarah', 'McRoy', '10268'),
#  ('Sarah', 'McRoy', '10418'),
#  ('Michael', 'Donnermeyer', '10296'),
#  ('Maria', 'Hernandez', '10115'),
#  ('Maria', 'Hernandez', '10163'),
#  ('Maria', 'Hernandez', '10337'),
#  ('Dan', 'Lewis', '10131'),
#  ('Dan', 'Lewis', '10146'),
#  ('Dan', 'Lewis', '10353'),
#  ('Martha', 'Larsson', '10167'),
#  ('Martha', 'Larsson', '10291'),
#  ('Martha', 'Larsson', '10389'),
#  ('Sue', 'Frick', '10250'),
#  ('Sue', 'Frick', '10257'),
#  ('Sue', 'Frick', '10400'),
#  ('Sue', 'Frick', '10407'),
#  ('Roland ', 'Mendel', '10164'),
#  ('Roland ', 'Mendel', '10170'),
#  ('Roland ', 'Mendel', '10392'),
#  ('Leslie', 'Murphy', '10196'),
#  ('Leslie', 'Murphy', '10245'),
#  ('Yu', 'Choi', '10242'),
#  ('Yu', 'Choi', '10319'),
#  ('Martín ', 'Sommer', '10126'),
#  ('Martín ', 'Sommer', '10214'),
#  ('Martín ', 'Sommer', '10348'),
#  ('Violeta', 'Benitez', '10166'),
#  ('Violeta', 'Benitez', '10321'),
#  ('Violeta', 'Benitez', '10388'),
#  ('Sean', 'Clenahan', '10193'),
#  ('Sean', 'Clenahan', '10265'),
#  ('Sean', 'Clenahan', '10415'),
#  ('Franco', 'Ricotti', '10157'),
#  ('Franco', 'Ricotti', '10218'),
#  ('Steve', 'Thompson', '10199'),
#  ('Steve', 'Thompson', '10215'),
#  ('José Pedro ', 'Roel', '10184'),
#  ('José Pedro ', 'Roel', '10303'),
#  ('Rosa', 'Salazar', '10109'),
#  ('Rosa', 'Salazar', '10236'),
#  ('Rosa', 'Salazar', '10331'),
#  ('Sue', 'Taylor', '10149'),
#  ('Sue', 'Taylor', '10219'),
#  ('Thomas ', 'Smith', '10186'),
#  ('Thomas ', 'Smith', '10213'),
#  ('Valarie', 'Franco', '10207'),
#  ('Valarie', 'Franco', '10243'),
#  ('Tony', 'Snowden', '10138'),
#  ('Tony', 'Snowden', '10179'),
#  ('Tony', 'Snowden', '10360'),
#  ('Tony', 'Snowden', '10399')]

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
cur.execute('''
    SELECT customerFirstName, customerLastName
    ''')

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
